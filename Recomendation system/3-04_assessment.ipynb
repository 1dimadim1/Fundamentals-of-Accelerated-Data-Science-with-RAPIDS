# %% [markdown]
# <div align="center"><a href="https://www.nvidia.com/en-us/deep-learning-ai/education/"><img src="./images/DLI_Header.png"></a></div>

# %% [markdown]
# Welcome to the assessment for this course. While we have gone over a variety of algorithms, we haven't done the most important part. We still need to serve a user a recommendation!
#
# Not a problem. We have all the pieces, time to put them together. For this assessment, we've constructed a skeleton for an end-to-end recommender system by copying over some code from Labs 1 and 2. By using what we've learned about the strengths and weaknesses of these algorithms, it will be up to you to apply them in the correct places.
#
# The code we have from the previous lab is:
# * [als.py](assessment/als.py) - Train and predict with an alternating least squares model
# * [dataset.py](assessment/dataset.py) - Prepare a dataset into a tf.data
# * [wide_and_deep.py](assessment/wide_and_deep.py) Construct a Wide & Deep TensorFlow model
# * [utils.py](assessment/utils.py) - Helper functions such as calculating RMSE
#
# As a reference, we can also unzip the packaged notebooks from the previous lab by uploading them (with the upward pointing arrow above the file menu) and running the cell block below. Please keep in mind that these previous lab notebooks won't run in this lab3 coding environment.

# %%
# !unzip lab1_work.zip -d lab1/
# !unzip lab2_work.zip -d lab2/
# Out:
# unzip:  cannot find or open lab1_work.zip, lab1_work.zip.zip or lab1_work.zip.ZIP.
# unzip:  cannot find or open lab2_work.zip, lab2_work.zip.zip or lab2_work.zip.ZIP.

# %% [markdown]
# Let's get started. Here's the total pipeline we'll be constructing.
#
# <img src="images/endtoend.png" height="300" width="500"/>
#
# The goal is to create two python files, [trainer.py](assessment/trainer.py) and [client.py](assessment/client.py). [trainer.py](assessment/trainer.py) will train both the Candidate Generator Model and the Candidate Scoring Model. [client.py](assessment/client.py) will return recommendations for a specified user from Triton.
#
# ## Scoring
# * [1. Model Training](#1.-Model-Training)
#  * [1.1 Candidate Generator Model](#1.1-Candidate-Generator-Model) - `30 Points`
#  * [1.2 Candidate Scoring Model](#1.2-Candidate-Scoring-Model) - `30 Points`
# * [2. Model Deployment](#2.-Model-Deployment)
#  * [2.1 Triton](#2.1-Triton) - `20 Points`
#  * [2.2 Client Application](#2.2-Client-Application) - `20 Points`
#
# ## 1. Model Training
#
# In [trainer.py](assessment/trainer.py), we have four functions:
# * `get_als_model`: Initializes and trains an ALS Model
# * `get_wide_and_deep_model`: Initializes and trains a Wide & Deep Model
# * `get_candidate_generator`: Creates a Candidate Generator Model
# * `get_candidate_scoring_model`: Creates a Candidate Scoring Model
#
# Each of them have a number of `FIXME`s.
#
# ### 1.1 Candidate Generator Model
# For `get_candidate_generator`, implement either a ALS (`get_als_model`) or Wide & Deep model (`get_wide_and_deep_model`). It will be trained on the ratings data below.

# %%
import pandas as pd

ratings = pd.read_csv("data/task_3_ratings.csv")
ratings.head()
# Out:
#    user_index  item_index  overall  valid
# 0      180332         781      1.0  False
# 1       55433         781      2.0  False
# 2       34202         781      5.0  False
# 3       77087         781      4.0  False
# 4       67012         781      1.0  False

# %% [markdown]
# The Candidate Generator is focused on speed, and is meant to quickly reduce our item catalogue down to a few hundred that our user might like.
#
# One way we can speed up predictions for our users is to cache the results of the Candidate Generator. If we do this, including contextual information such as time and location is not so straightforward. We would need to cache different results for different combinations of time and place for the variety of different ways users can interact with our system.
#
# Let's keep things simple for now, and instead just focus on `user_index`, `item_index`, and `overall`.
#
# Whether ALS or Wide and Deep is chosen, the Candidate Generator must be fast in both training and prediction:
#
# * The Candidate Generator should be trained in less than 15 seconds `10 points`.
# * The Candidate Generator should have a Root Mean Squared Error of less than 1.3 on the Validation Dataset `10 points`.
# * The Candidate Generator should make predictions for the Validation Dataset in 0.005 seconds `10 points`.
#
# **While either algorithm can hypothetically pass these requirements, one will be significantly easier to implement than the other.**
#
# ### 1.2 Candidate Scoring Model
#
# The goal of the Candidate Scorer Model is to take the candidates from the Generator Model, and to rank them in order of the user's predicted preference. While the Generator Model is focused on speed, the Scoring Model is focused on accuracy. Additionally, the Scoring Model can more easily incorporate contextual information as it is ran when a user asks for a recommendation.
#
# When we trained our Wide and Deep Model in Lab 2, our `metadata` was already joined with user rankings. However, in production when we're making a prediction for one user, our predictions will be based on our separate metadata table:

# %%
metadata = pd.read_csv("data/task_3_metadata.csv")
metadata.head()
# Out:
#    item_index  brand_index category_0_0                 category_0_1  \
# 0           0            0  Electronics             GPS & Navigation
# 1           1            0  Electronics      Computers & Accessories
# 2           2          337  Electronics  eBook Readers & Accessories
# 3           3         3146  Electronics       Accessories & Supplies
# 4           4            0  Electronics      Computers & Accessories
#
#                       category_0_2            category_0_3 category_1_0  \
# 0                      Vehicle GPS            Trucking GPS          NaN
# 1  Touch Screen Tablet Accessories     Chargers & Adapters          NaN
# 2                   Power Adapters                     NaN          NaN
# 3        Audio & Video Accessories  TV Accessories & Parts          NaN
# 4                          Tablets                     NaN          NaN
#
#   category_1_1 category_1_2 category_1_3  ...  category_1_2_index  \
# 0          NaN          NaN          NaN  ...                 101
# 1          NaN          NaN          NaN  ...                 101
# 2          NaN          NaN          NaN  ...                 101
# 3          NaN          NaN          NaN  ...                 101
# 4          NaN          NaN          NaN  ...                 101
#
#    salesRank_Electronics  salesRank_Camera  salesRank_Computers  \
# 0               147236.0           18665.5              14369.5
# 1               147236.0           18665.5              14369.5
# 2               147236.0           18665.5              14369.5
# 3               147236.0           18665.5              14369.5
# 4               147236.0           18665.5              14369.5
#
#    salesRank_CellPhones  salesRank_CellPhones_NA  salesRank_Electronics_NA  \
# 0              254050.0                    False                     False
# 1              254050.0                    False                     False
# 2              254050.0                    False                     False
# 3              254050.0                    False                     False
# 4              254050.0                    False                     False
#
#    salesRank_Camera_NA  salesRank_Computers_NA  price_filled
# 0                False                   False        299.99
# 1                False                   False         49.95
# 2                False                   False         19.65
# 3                False                   False         29.99
# 4                False                   False        188.88
#
# [5 rows x 21 columns]

# %% [markdown]
# We should update our training data to reflect this. We've kept our training data from Lab 2.

# %%
lab_2_data = pd.read_csv("data/task_2_wide_and_deep.csv")
lab_2_data.head()
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (9,10,11,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        reviewerID        asin  overall  unixReviewTime brand category_0_0  \
# 0   ARA6X7G3KBX39  B00005B4BW      1.0      1042243200   NaN  Electronics
# 1  A231WM2Z2JL0U3  B00005B4BW      2.0       965433600   NaN  Electronics
# 2  A1O130H3XTF5WF  B00005B4BW      5.0       954460800   NaN  Electronics
# 3  A2IIZ25SZSQGCC  B00005B4BW      4.0      1030233600   NaN  Electronics
# 4  A2BBDPGILE8EN4  B00005B4BW      1.0      1009497600   NaN  Electronics
#
#      category_0_1       category_0_2  category_0_3 category_1_0  ...  \
# 0  Camera & Photo  Lighting & Studio  Photo Studio          NaN  ...
# 1  Camera & Photo  Lighting & Studio  Photo Studio          NaN  ...
# 2  Camera & Photo  Lighting & Studio  Photo Studio          NaN  ...
# 3  Camera & Photo  Lighting & Studio  Photo Studio          NaN  ...
# 4  Camera & Photo  Lighting & Studio  Photo Studio          NaN  ...
#
#   user_index item_index brand_index  als_prediction  user_embed_0  \
# 0     180332        781           0        3.105687      1.451223
# 1      55433        781           0        3.532970      1.650880
# 2      34202        781           0        3.962095      1.851401
# 3      77087        781           0        2.661104      1.243477
# 4      67012        781           0        3.232237      1.510355
#
#    user_embed_1  item_embed_0  item_embed_1  category_0_2_index  \
# 0     -2.425463      0.715103     -1.195170                  83
# 1     -2.759162      0.769520     -1.286120                  83
# 2     -3.094298      0.820172     -1.370778                  83
# 3     -2.078256      0.770355     -1.287510                  83
# 4     -2.524297      0.709057     -1.185062                  83
#
#    category_1_2_index
# 0                 101
# 1                 101
# 2                 101
# 3                 101
# 4                 101
#
# [5 rows x 34 columns]

# %% [markdown]
# Update the `get_candidate_scoring_model` in [trainer.py](assessment/trainer.py) in order to calculate the [Gaussian Rank](https://medium.com/rapids-ai/gauss-rank-transformation-is-100x-faster-with-rapids-and-cupy-7c947e3397da) of our `metadata`'s `salesRank_Electronics` column. Then, join this column into `lab_2_data`.
#
# Finally, choose one of either ALS (`get_als_model`) or Wide and Deep model (`get_wide_and_deep_model`) to implement as the Candidate Scoring Model.
#
# Whether ALS or Wide and Deep is chosen, the Candidate Scoring Model needs to meet the following requirements:
#
# * The Candidate Scoring Model should be trained in less than 600 seconds `10 points`.
# * The Candidate Scoring Model should have a Root Mean Squared Error of less than 1.175 on the Validation Dataset `10 points`.
# * The Candidate Scoring Model should make predictions for the Validation Dataset in 30 seconds `10 points`.
#
# **While either algorithm can hypothetically pass these requirements, one will be significantly easier to implement than the other.** Run the below cell to verify that [trainer.py](assessment/trainer.py) has been correctly implemented for both Candidate Generation and Candidate Scoring, meeting all of the above requirements.

# %%
# !python3 -m assessment.trainer
# Out:
# 2022-05-18 23:24:00.050035: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-05-18 23:24:02.508869: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-05-18 23:24:02.508988: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-05-18 23:24:02.509134: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1038] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-18 23:24:02.509688: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Found device 0 with properties:
# pciBusID: 0000:00:1e.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2022-05-18 23:24:02.509728: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-05-18 23:24:02.509819: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-05-18 23:24:02.509854: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2022-05-18 23:24:02.509891: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-05-18 23:24:02.509925: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-05-18 23:24:02.509981: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.11
# 2022-05-18 23:24:02.510013: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2022-05-18 23:24:02.510050: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2022-05-18 23:24:02.510136: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1038] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-18 23:24:02.510731: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1038] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-18 23:24:02.511241: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1888] Adding visible gpu devices: 0
# RMSE 4.721785691996279
# RMSE 4.777042450664268
# RMSE 4.574401266212359
# RMSE 3.1795387463887668
# RMSE 1.6714368499821368
# RMSE 1.40913915503296
# RMSE 1.3130888887331569
# RMSE 1.2546375886074645
# RMSE 1.229052261100126
# Candidate Generation Training Time 6.579676628112793
# Candidate Generation Prediction Time 0.0023899078369140625
# Candidate Generation RMSE 1.229052261100126
# sys:1: DtypeWarning: Columns (9,10,11,12) have mixed types.Specify dtype option on import or set low_memory=False.
# 2022-05-18 23:24:17.758930: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-05-18 23:24:17.759150: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1038] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-18 23:24:17.759714: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Found device 0 with properties:
# pciBusID: 0000:00:1e.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2022-05-18 23:24:17.759758: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-05-18 23:24:17.759792: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-05-18 23:24:17.759813: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2022-05-18 23:24:17.759830: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-05-18 23:24:17.759848: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-05-18 23:24:17.759868: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.11
# 2022-05-18 23:24:17.759885: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2022-05-18 23:24:17.759912: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2022-05-18 23:24:17.760000: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1038] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-18 23:24:17.760545: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1038] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-18 23:24:17.761023: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1888] Adding visible gpu devices: 0
# 2022-05-18 23:24:17.761071: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-05-18 23:24:17.761209: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1287] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-05-18 23:24:17.761228: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1293]      0
# 2022-05-18 23:24:17.761241: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1306] 0:   N
# 2022-05-18 23:24:17.761350: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1038] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-18 23:24:17.761974: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1038] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-18 23:24:17.762561: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1038] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-18 23:24:17.763120: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7554 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:1e.0, compute capability: 7.5)
# 2022-05-18 23:24:18.796118: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-05-18 23:24:18.814765: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2500000000 Hz
# Epoch 1/2
# 2022-05-18 23:24:19.992049: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-05-18 23:24:19.992527: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 1462/1462 [==============================] - 103s 69ms/step - loss: 2.2853 - rmse: 1.4454
# {'val_loss': 2.4291801, 'val_rmse': 1.1921388}
# Epoch 2/2
# 1462/1462 [==============================] - 96s 66ms/step - loss: 0.8868 - rmse: 0.9413
# {'val_loss': 2.133243, 'val_rmse': 1.0059884}
# Candidate Scorer Training Time 214.85400938987732
# Candidate Scorer Prediction Time 11.3607337474823
# Candidate Scorer RMSE 1.160563113700005
# 2022-05-18 23:28:03.812514: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# Tests pass!

# %% [markdown]
# ## 2. Model Deployment
#
# If the above code passed, it should have saved the components for the Candidate Generation Model and the Candidate Scoring Model. We'll need to load them into Triton and our client application. Let's start with Triton.
#
# ### 2.1 Triton
#
# Open the File Browser (Ctrl/Command + Shift + F) to see the lab's file directory on the left (The list may need to be refreshed). The Candidate Scoring Model should now be saved to a folder on the left called `candidate_scorer`. Load it into `model_repository` using the following structure:
#
# `model_repository/
#   candidate_scorer/
#     config.pbtxt
#     1/
#       model.savedmodel/
#         <tensorflow_saved_model_files>/
#           ...
# `
#
# Feel free to use the [previous lab](3-03_triton.ipynb) as a guide. The below cell will **delete and rebuild** a `candidate_scorer` folder in `model_repository`. Please complete the `FIXME` below.

# %%
# !rm -rf model_repository/candidate_scorer ||:; mkdir model_repository/candidate_scorer

# %%
import tensorflow as tf
from nvtabular.inference.triton.ensemble import export_tensorflow_model

model_name = 'candidate_scorer'
model = tf.keras.models.load_model(model_name)
tf_config = export_tensorflow_model(model, model_name, 'model_repository/'+model_name, version=1)
# Out:
# INFO:tensorflow:Assets written to: model_repository/candidate_scorer/1/model.savedmodel/assets

# %% [markdown]
# Finally, let's verify that the model is running on Triton. `20 points`

# %%
import tritonhttpclient

try:
    triton_client = tritonhttpclient.InferenceServerClient(url="triton:8000", verbose=True)
    print("client created.")
except Exception as e:
    print("channel creation failed: " + str(e))

triton_client.get_model_repository_index()
triton_client.load_model(model_name=model_name)
triton_client.is_model_ready(model_name)
# Out:
# client created.
# POST v2/repository/index, headers None
#
# <HTTPSocketPoolResponse status=200 headers={'content-type': 'application/json', 'content-length': '59'}>
# bytearray(b'[{"name":"candidate_scorer","version":"1","state":"READY"}]')
# POST v2/repository/models/candidate_scorer/load, headers None
#
# <HTTPSocketPoolResponse status=200 headers={'content-type': 'application/json', 'content-length': '0'}>
# Loaded model 'candidate_scorer'
# GET v2/models/candidate_scorer/ready, headers None
# <HTTPSocketPoolResponse status=200 headers={'content-length': '0', 'content-type': 'text/plain'}>
# True

# %% [markdown]
# Once verified, run the code below to free the GPU for the next section.

# %%
import IPython
app = IPython.Application.instance()
app.kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}

# %% [markdown]
# ### 2.2 Client Application
#
# We have our models, and our Candidate Scorer is loaded into Triton. Time for the magic to happen. Let's string everything together in [client.py](assessment/client.py) where there are a number of TODOs.
#
# First, load your Candidate Generation Model and use it to find a user's top 16 (`BATCH_SIZE`) recommendations.
# Second, specify the metadata columns specific to your Candidate Scoring Model.
# Finally, fix the `for` loop to format the data for Triton.
#
# For both the Candidate Generation Model and the Candidate Scoring Model, CuPy's/NumPy's [argpartition](https://numpy.org/doc/stable/reference/generated/numpy.argpartition.html) function are used to quickly separate top scoring items versus low scoring items.
#
# The following tests are in place:
# * Prediction for one user's top 16 items takes less than `2` seconds `10 points`
# * The average predicted score for user `131676`'s top 4 recommended items is greater than `4.2`. `10 points`

# %%
# !python3 -m assessment.client
# Out:
# 2022-05-18 23:37:03.202498: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-05-18 23:37:05.035846: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-05-18 23:37:05.035963: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-05-18 23:37:05.036137: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1038] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-18 23:37:05.036505: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Found device 0 with properties:
# pciBusID: 0000:00:1e.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2022-05-18 23:37:05.036548: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-05-18 23:37:05.036622: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-05-18 23:37:05.036660: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2022-05-18 23:37:05.036702: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-05-18 23:37:05.036740: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-05-18 23:37:05.036798: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.11
# 2022-05-18 23:37:05.036835: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2022-05-18 23:37:05.036878: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2022-05-18 23:37:05.036970: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1038] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-18 23:37:05.037356: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1038] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-18 23:37:05.037677: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1888] Adding visible gpu devices: 0
# client created.
# POST v2/models/candidate_scorer/infer, headers {'Inference-Header-Content-Length': 770}
# b'{"inputs":[{"name":"user_index","shape":[16,1],"datatype":"INT32","parameters":{"binary_data_size":64}},{"name":"item_index","shape":[16,1],"datatype":"INT32","parameters":{"binary_data_size":64}},{"name":"brand_index","shape":[16,1],"datatype":"INT32","parameters":{"binary_data_size":64}},{"name":"price_filled","shape":[16,1],"datatype":"FP32","parameters":{"binary_data_size":64}},{"name":"salesRank_Electronics","shape":[16,1],"datatype":"FP32","parameters":{"binary_data_size":64}},{"name":"category_0_2_index","shape":[16,1],"datatype":"INT32","parameters":{"binary_data_size":64}},{"name":"category_1_2_index","shape":[16,1],"datatype":"INT32","parameters":{"binary_data_size":64}}],"outputs":[{"name":"tf.__operators__.add","parameters":{"binary_data":false}}]}\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00M\xf2\x00\x00z\xe8\x00\x00L\xc8\x00\x00\xcc\xe8\x00\x00*\xaf\x00\x00*\xf1\x00\x00\x0b\xf5\x00\x00F\xeb\x00\x00\x86\xe9\x00\x00\xf2\xf5\x00\x00\xfc\xc6\x00\x00n\xe7\x00\x00:\xcd\x00\x00H\xc6\x00\x00\xe2\xf5\x00\x00\xe6\xbc\x00\x00-\x05\x00\x00\x9c\x05\x00\x00\x03\x00\x00\x00\x03\x00\x00\x00\x03\x00\x00\x00\xd3\x06\x00\x00\x03\x00\x00\x00\x03\x00\x00\x00\xbc\x02\x00\x00\x03\x00\x00\x00\x03\x00\x00\x00\xbb\x01\x00\x00\x03\x00\x00\x00\x03\x00\x00\x00\x03\x00\x00\x00\x03\x00\x00\x00&\x17\x9a@\xd8\x19\xf5?H\xf3F@\xca1"@\xae4\x86@<\xcdf@\x9dq\t@\x18\x85\x99@\xd9x\x08@M\x0b=@U\xf87@(0@@\xa0X\xb9?8\xc1[@\x80\xe0l@\xb5\x95\x87@f\xaa\x8e@\xc4\xd4\x83@\xfc\x9fi@L\x14\x84@,B[@\x8f\xc9\x8c@m\x1f\x95@ "\x86@\x06\xad\x84@\x08\xad\x98@?\xc4h@\xc3\x11\x83@\x7f\xfcl@\x05\xda\xc4?\xbf^\x98@\xca\xaab@T\x00\x00\x00\x0e\x00\x00\x00\x04\x00\x00\x00\n\x00\x00\x00X\x00\x00\x00\x9a\x00\x00\x00\x04\x00\x00\x005\x00\x00\x00X\x00\x00\x00\x1f\x00\x00\x00S\x00\x00\x00\x12\x00\x00\x00\x1f\x00\x00\x00S\x00\x00\x00\'\x00\x00\x00"\x00\x00\x00h\x00\x00\x00h\x00\x00\x00h\x00\x00\x00h\x00\x00\x00h\x00\x00\x00h\x00\x00\x00h\x00\x00\x00q\x00\x00\x00h\x00\x00\x00h\x00\x00\x00h\x00\x00\x00h\x00\x00\x00h\x00\x00\x00h\x00\x00\x00h\x00\x00\x00h\x00\x00\x00'
# <HTTPSocketPoolResponse status=200 headers={'content-type': 'application/json', 'content-length': '427'}>
# bytearray(b'{"model_name":"candidate_scorer","model_version":"1","outputs":[{"name":"tf.__operators__.add","datatype":"FP32","shape":[16,1],"data":[4.607283115386963,3.822737693786621,3.3772926330566408,4.032763481140137,4.205111503601074,4.055320739746094,3.971539258956909,4.566665172576904,4.127745151519775,4.33643913269043,4.040746212005615,4.125417709350586,3.803406238555908,3.862948417663574,4.818838596343994,4.607215881347656]}]}')
# Ranking Time 0.6097781658172607
# Top Indexes [60230 48358 62946 62029]
# Top Predictions [4.56666517 4.60721588 4.8188386  4.60728312]
# Average Rating 4.650000691413879
# Tests pass!

# %% [markdown]
# Got both `Tests pass!` for [1. Model Training](#1.-Model-Training) and [2. Model Deployment](#2.-Model-Deployment)? Run the cell below for the final check! This will verify your code against our assessment server, and if it passes, will qualify you for a certificate.

# %%
from run_assessment import run_assessment
run_assessment()
# Out:
# client created.
# RMSE 4.718851443031366
# RMSE 4.797394808409796
# RMSE 4.785367895664642
# RMSE 4.398347769552596
# RMSE 2.899887773228895
# RMSE 1.689366682190195
# RMSE 1.4579123862754801
# RMSE 1.387099401970359
# RMSE 1.3682824691342892
# RMSE 1.3435129170521494
# RMSE 1.3227330016855219
# RMSE 1.3084105025442048
# RMSE 1.2929580247270607
# RMSE 1.277538617396971
# RMSE 1.266743875837483
# RMSE 1.259812485583696
# RMSE 1.2514967983725307
# RMSE 1.2388522170946847
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3357: DtypeWarning: Columns (9,10,11,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Epoch 1/2
# 1462/1462 [==============================] - 103s 69ms/step - loss: 2.2025 - rmse: 1.4225
# {'val_loss': 2.4151335, 'val_rmse': 1.1853796}
# Epoch 2/2
# 1462/1462 [==============================] - 101s 69ms/step - loss: 0.9328 - rmse: 0.9657
# {'val_loss': 2.1408172, 'val_rmse': 1.0128958}
# GET v2/models/candidate_scorer/ready, headers None
# <HTTPSocketPoolResponse status=200 headers={'content-length': '0', 'content-type': 'text/plain'}>
# POST v2/models/candidate_scorer/infer, headers {'Inference-Header-Content-Length': 770}
# b'{"inputs":[{"name":"user_index","shape":[16,1],"datatype":"INT32","parameters":{"binary_data_size":64}},{"name":"item_index","shape":[16,1],"datatype":"INT32","parameters":{"binary_data_size":64}},{"name":"brand_index","shape":[16,1],"datatype":"INT32","parameters":{"binary_data_size":64}},{"name":"price_filled","shape":[16,1],"datatype":"FP32","parameters":{"binary_data_size":64}},{"name":"salesRank_Electronics","shape":[16,1],"datatype":"FP32","parameters":{"binary_data_size":64}},{"name":"category_0_2_index","shape":[16,1],"datatype":"INT32","parameters":{"binary_data_size":64}},{"name":"category_1_2_index","shape":[16,1],"datatype":"INT32","parameters":{"binary_data_size":64}}],"outputs":[{"name":"tf.__operators__.add","parameters":{"binary_data":false}}]}\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00M\xf2\x00\x00z\xe8\x00\x00L\xc8\x00\x00\xcc\xe8\x00\x00*\xaf\x00\x00*\xf1\x00\x00\x0b\xf5\x00\x00F\xeb\x00\x00\x86\xe9\x00\x00\xf2\xf5\x00\x00\xfc\xc6\x00\x00n\xe7\x00\x00:\xcd\x00\x00H\xc6\x00\x00\xe2\xf5\x00\x00\xe6\xbc\x00\x00-\x05\x00\x00\x9c\x05\x00\x00\x03\x00\x00\x00\x03\x00\x00\x00\x03\x00\x00\x00\xd3\x06\x00\x00\x03\x00\x00\x00\x03\x00\x00\x00\xbc\x02\x00\x00\x03\x00\x00\x00\x03\x00\x00\x00\xbb\x01\x00\x00\x03\x00\x00\x00\x03\x00\x00\x00\x03\x00\x00\x00\x03\x00\x00\x00&\x17\x9a@\xd8\x19\xf5?H\xf3F@\xca1"@\xae4\x86@<\xcdf@\x9dq\t@\x18\x85\x99@\xd9x\x08@M\x0b=@U\xf87@(0@@\xa0X\xb9?8\xc1[@\x80\xe0l@\xb5\x95\x87@f\xaa\x8e@\xc4\xd4\x83@\xfc\x9fi@L\x14\x84@,B[@\x8f\xc9\x8c@m\x1f\x95@ "\x86@\x06\xad\x84@\x08\xad\x98@?\xc4h@\xc3\x11\x83@\x7f\xfcl@\x05\xda\xc4?\xbf^\x98@\xca\xaab@T\x00\x00\x00\x0e\x00\x00\x00\x04\x00\x00\x00\n\x00\x00\x00X\x00\x00\x00\x9a\x00\x00\x00\x04\x00\x00\x005\x00\x00\x00X\x00\x00\x00\x1f\x00\x00\x00S\x00\x00\x00\x12\x00\x00\x00\x1f\x00\x00\x00S\x00\x00\x00\'\x00\x00\x00"\x00\x00\x00h\x00\x00\x00h\x00\x00\x00h\x00\x00\x00h\x00\x00\x00h\x00\x00\x00h\x00\x00\x00h\x00\x00\x00q\x00\x00\x00h\x00\x00\x00h\x00\x00\x00h\x00\x00\x00h\x00\x00\x00h\x00\x00\x00h\x00\x00\x00h\x00\x00\x00h\x00\x00\x00'
# <HTTPSocketPoolResponse status=200 headers={'content-type': 'application/json', 'content-length': '427'}>
# bytearray(b'{"model_name":"candidate_scorer","model_version":"1","outputs":[{"name":"tf.__operators__.add","datatype":"FP32","shape":[16,1],"data":[4.607283115386963,3.822737693786621,3.3772926330566408,4.032763481140137,4.205111503601074,4.055320739746094,3.971539258956909,4.566665172576904,4.127745151519775,4.33643913269043,4.040746212005615,4.125417709350586,3.803406238555908,3.862948417663574,4.818838596343994,4.607215881347656]}]}')
# Congratulations! You passed the assessment!
# See instructions below to generate a certificate.

# %% [markdown]
# ## Generate a Certificate
# If you passed the assessment, please return to the course page (shown below) and click the "ASSESS TASK" button, which will generate your certificate for the course.
#
# <img src="images/run_assess_task.png" height="300" width="500"/>

# %% [markdown]
# <div align="center"><a href="https://www.nvidia.com/en-us/deep-learning-ai/education/"><img src="./images/DLI_Header.png"></a></div>
